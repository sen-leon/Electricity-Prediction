# %%
#setup:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

from wetterdienst.provider.dwd.observation import DwdObservationRequest, DwdObservationDataset, DwdObservationPeriod, DwdObservationResolution
# from wetterdienst import Wetterdienst, Resolution, Period, Parameter
from wetterdienst.provider.dwd.mosmix import(
    DwdMosmixRequest,
    DwdForecastDate,
    DwdMosmixType,
    )

from pprint import pprint

# %%
def output_section(title, data):  # pragma: no cover
    print("-" * len(title))
    print(title)
    print("-" * len(title))
    print(data)
    print()

# %%
from wetterdienst import Settings
Settings.tidy = True
Settings.humanize =True
Settings.si_units = True
# API = Wetterdienst(provider="dwd", network="observation")

sample_request = DwdMosmixRequest(
        parameter=["DD", "ww"],
        start_issue=DwdForecastDate.LATEST,  # automatically set if left empty
        mosmix_type=DwdMosmixType.LARGE,
    )


# print(dir(sample_request))
pprint(sample_request.discover())

def mosmix_request(params, station_ids):
    """Retrieve stations_result of mosmix forecast."""
    request = DwdMosmixRequest(
        parameter=[params],
        start_issue=DwdForecastDate.LATEST,  # automatically set if left empty
        mosmix_type=DwdMosmixType.LARGE,
    )
    
    stations = request.filter_by_station_id(station_ids)
    # stations=request
    return stations#["station_id"]
# Out:
# {'large': {'cloud_base_convective': {'origin': 'm', 'si': 'm'},
#            'cloud_cover_above_7_km': {'origin': 'pct', 'si': 'pct'},
#            'cloud_cover_below_1000_ft': {'origin': 'pct', 'si': 'pct'},
#            'cloud_cover_below_500_ft': {'origin': 'pct', 'si': 'pct'},
#            'cloud_cover_below_7_km': {'origin': 'pct', 'si': 'pct'},
#            'cloud_cover_between_2_to_7_km': {'origin': 'pct', 'si': 'pct'},
#            'cloud_cover_effective': {'origin': 'pct', 'si': 'pct'},
#            'cloud_cover_total': {'origin': 'pct', 'si': 'pct'},
#            'error_absolute_pressure_air_site': {'origin': 'Pa', 'si': 'Pa'},
#            'error_absolute_temperature_air_mean_200': {'origin': 'K',
#                                                        'si': 'K'},
#            'error_absolute_temperature_dew_point_mean_200': {'origin': 'K',
#                                                              'si': 'K'},
#            'error_absolute_wind_direction': {'origin': 'deg', 'si': 'deg'},
#            'error_absolute_wind_speed': {'origin': 'm / s', 'si': 'm / s'},
#            'evapotranspiration_potential_last_24h': {'origin': 'kg / m ** 2',
#                                                      'si': 'kg / m ** 2'},
#            'precipitation_duration': {'origin': 's', 'si': 's'},
#            'precipitation_height_last_12h': {'origin': 'kg / m ** 2',
#                                              'si': 'kg / m ** 2'},
#            'precipitation_height_last_1h': {'origin': 'kg / m ** 2',
#                                             'si': 'kg / m ** 2'},
#            'precipitation_height_last_24h': {'origin': 'kg / m ** 2',
#                                              'si': 'kg / m ** 2'},
#            'precipitation_height_last_3h': {'origin': 'kg / m ** 2',
#                                             'si': 'kg / m ** 2'},
#            'precipitation_height_last_6h': {'origin': 'kg / m ** 2',
#                                             'si': 'kg / m ** 2'},
#            'precipitation_height_liquid_significant_weather_last_1h': {'origin': 'kg '
#                                                                                  '/ '
#                                                                                  'm '
#                                                                                  '** '
#                                                                                  '2',
#                                                                        'si': 'kg '
#                                                                              '/ '
#                                                                              'm '
#                                                                              '** '
#                                                                              '2'},
#            'precipitation_height_significant_weather_last_12h': {'origin': 'kg '
#                                                                            '/ '
#                                                                            'm '
#                                                                            '** '
#                                                                            '2',
#                                                                  'si': 'kg / m '
#                                                                        '** 2'},
#            'precipitation_height_significant_weather_last_1h': {'origin': 'kg '
#                                                                           '/ m '
#                                                                           '** '
#                                                                           '2',
#                                                                 'si': 'kg / m '
#                                                                       '** 2'},
#            'precipitation_height_significant_weather_last_24h': {'origin': 'kg '
#                                                                            '/ '
#                                                                            'm '
#                                                                            '** '
#                                                                            '2',
#                                                                  'si': 'kg / m '
#                                                                        '** 2'},
#            'precipitation_height_significant_weather_last_3h': {'origin': 'kg '
#                                                                           '/ m '
#                                                                           '** '
#                                                                           '2',
#                                                                 'si': 'kg / m '
#                                                                       '** 2'},
#            'precipitation_height_significant_weather_last_6h': {'origin': 'kg '
#                                                                           '/ m '
#                                                                           '** '
#                                                                           '2',
#                                                                 'si': 'kg / m '
#                                                                       '** 2'},
#            'pressure_air_site_reduced': {'origin': 'Pa', 'si': 'Pa'},
#            'probability_drizzle_last_12h': {'origin': 'pct', 'si': 'pct'},
#            'probability_drizzle_last_1h': {'origin': 'pct', 'si': 'pct'},
#            'probability_drizzle_last_6h': {'origin': 'pct', 'si': 'pct'},
#            'probability_fog_last_12h': {'origin': 'pct', 'si': 'pct'},
#            'probability_fog_last_1h': {'origin': 'pct', 'si': 'pct'},
#            'probability_fog_last_24h': {'origin': 'pct', 'si': 'pct'},
#            'probability_fog_last_6h': {'origin': 'pct', 'si': 'pct'},
#            'probability_precipitation_convective_last_12h': {'origin': 'pct',
#                                                              'si': 'pct'},
#            'probability_precipitation_convective_last_1h': {'origin': 'pct',
#                                                             'si': 'pct'},
#            'probability_precipitation_convective_last_6h': {'origin': 'pct',
#                                                             'si': 'pct'},
#            'probability_precipitation_freezing_last_12h': {'origin': 'pct',
#                                                            'si': 'pct'},
#            'probability_precipitation_freezing_last_1h': {'origin': 'pct',
#                                                           'si': 'pct'},
#            'probability_precipitation_freezing_last_6h': {'origin': 'pct',
#                                                           'si': 'pct'},
#            'probability_precipitation_height_gt_0_0_mm_last_12h': {'origin': 'pct',
#                                                                    'si': 'pct'},
#            'probability_precipitation_height_gt_0_0_mm_last_24h': {'origin': 'pct',
#                                                                    'si': 'pct'},
#            'probability_precipitation_height_gt_0_0_mm_last_6h': {'origin': 'pct',
#                                                                   'si': 'pct'},
#            'probability_precipitation_height_gt_0_1_mm_last_1h': {'origin': 'pct',
#                                                                   'si': 'pct'},
#            'probability_precipitation_height_gt_0_2_mm_last_12h': {'origin': 'pct',
#                                                                    'si': 'pct'},
#            'probability_precipitation_height_gt_0_2_mm_last_1h': {'origin': 'pct',
#                                                                   'si': 'pct'},
#            'probability_precipitation_height_gt_0_2_mm_last_24h': {'origin': 'pct',
#                                                                    'si': 'pct'},
#            'probability_precipitation_height_gt_0_2_mm_last_6h': {'origin': 'pct',
#                                                                   'si': 'pct'},
#            'probability_precipitation_height_gt_0_3_mm_last_1h': {'origin': 'pct',
#                                                                   'si': 'pct'},
#            'probability_precipitation_height_gt_0_5_mm_last_1h': {'origin': 'pct',
#                                                                   'si': 'pct'},
#            'probability_precipitation_height_gt_0_7_mm_last_1h': {'origin': 'pct',
#                                                                   'si': 'pct'},
#            'probability_precipitation_height_gt_10_0_mm_last_1h': {'origin': 'pct',
#                                                                    'si': 'pct'},
#            'probability_precipitation_height_gt_15_0_mm_last_1h': {'origin': 'pct',
#                                                                    'si': 'pct'},
#            'probability_precipitation_height_gt_1_0_mm_last_12h': {'origin': 'pct',
#                                                                    'si': 'pct'},
#            'probability_precipitation_height_gt_1_0_mm_last_1h': {'origin': 'pct',
#                                                                   'si': 'pct'},
#            'probability_precipitation_height_gt_1_0_mm_last_24h': {'origin': 'pct',
#                                                                    'si': 'pct'},
#            'probability_precipitation_height_gt_1_0_mm_last_6h': {'origin': 'pct',
#                                                                   'si': 'pct'},
#            'probability_precipitation_height_gt_25_0_mm_last_1h': {'origin': 'pct',
#                                                                    'si': 'pct'},
#            'probability_precipitation_height_gt_2_0_mm_last_1h': {'origin': 'pct',
#                                                                   'si': 'pct'},
#            'probability_precipitation_height_gt_3_0_mm_last_1h': {'origin': 'pct',
#                                                                   'si': 'pct'},
#            'probability_precipitation_height_gt_5_0_mm_last_12h': {'origin': 'pct',
#                                                                    'si': 'pct'},
#            'probability_precipitation_height_gt_5_0_mm_last_1h': {'origin': 'pct',
#                                                                   'si': 'pct'},
#            'probability_precipitation_height_gt_5_0_mm_last_24h': {'origin': 'pct',
#                                                                    'si': 'pct'},
#            'probability_precipitation_height_gt_5_0_mm_last_6h': {'origin': 'pct',
#                                                                   'si': 'pct'},
#            'probability_precipitation_last_12h': {'origin': 'pct', 'si': 'pct'},
#            'probability_precipitation_last_1h': {'origin': 'pct', 'si': 'pct'},
#            'probability_precipitation_last_24h': {'origin': 'pct', 'si': 'pct'},
#            'probability_precipitation_last_6h': {'origin': 'pct', 'si': 'pct'},
#            'probability_precipitation_liquid_last_12h': {'origin': 'pct',
#                                                          'si': 'pct'},
#            'probability_precipitation_liquid_last_1h': {'origin': 'pct',
#                                                         'si': 'pct'},
#            'probability_precipitation_liquid_last_6h': {'origin': 'pct',
#                                                         'si': 'pct'},
#            'probability_precipitation_solid_last_12h': {'origin': 'pct',
#                                                         'si': 'pct'},
#            'probability_precipitation_solid_last_1h': {'origin': 'pct',
#                                                        'si': 'pct'},
#            'probability_precipitation_solid_last_6h': {'origin': 'pct',
#                                                        'si': 'pct'},
#            'probability_precipitation_stratiform_last_12h': {'origin': 'pct',
#                                                              'si': 'pct'},
#            'probability_precipitation_stratiform_last_1h': {'origin': 'pct',
#                                                             'si': 'pct'},
#            'probability_precipitation_stratiform_last_6h': {'origin': 'pct',
#                                                             'si': 'pct'},
#            'probability_radiation_global_last_1h': {'origin': 'pct',
#                                                     'si': 'pct'},
#            'probability_sunshine_duration_relative_gt_0_pct_last_24h': {'origin': 'pct',
#                                                                         'si': 'pct'},
#            'probability_sunshine_duration_relative_gt_30_pct_last_24h': {'origin': 'pct',
#                                                                          'si': 'pct'},
#            'probability_sunshine_duration_relative_gt_60_pct_last_24h': {'origin': 'pct',
#                                                                          'si': 'pct'},
#            'probability_thunder_last_12h': {'origin': 'pct', 'si': 'pct'},
#            'probability_thunder_last_1h': {'origin': 'pct', 'si': 'pct'},
#            'probability_thunder_last_24h': {'origin': 'pct', 'si': 'pct'},
#            'probability_thunder_last_6h': {'origin': 'pct', 'si': 'pct'},
#            'probability_visibility_below_1000_m': {'origin': 'pct',
#                                                    'si': 'pct'},
#            'probability_wind_gust_ge_25_kn_last_12h': {'origin': 'pct',
#                                                        'si': 'pct'},
#            'probability_wind_gust_ge_25_kn_last_6h': {'origin': 'pct',
#                                                       'si': 'pct'},
#            'probability_wind_gust_ge_40_kn_last_12h': {'origin': 'pct',
#                                                        'si': 'pct'},
#            'probability_wind_gust_ge_40_kn_last_6h': {'origin': 'pct',
#                                                       'si': 'pct'},
#            'probability_wind_gust_ge_55_kn_last_12h': {'origin': 'pct',
#                                                        'si': 'pct'},
#            'probability_wind_gust_ge_55_kn_last_6h': {'origin': 'pct',
#                                                       'si': 'pct'},
#            'radiation_global': {'origin': '% [0..80]', 'si': '% [0..80]'},
#            'radiation_global_last_3h': {'origin': 'kJ / m ** 2',
#                                         'si': 'J / m ** 2'},
#            'radiation_sky_long_wave_last_3h': {'origin': 'kJ / m ** 2',
#                                                'si': 'J / m ** 2'},
#            'sunshine_duration': {'origin': 's', 'si': 's'},
#            'sunshine_duration_last_3h': {'origin': 's', 'si': 's'},
#            'sunshine_duration_relative_last_24h': {'origin': '-', 'si': '-'},
#            'sunshine_duration_yesterday': {'origin': 's', 'si': 's'},
#            'temperature_air_max_200': {'origin': 'K', 'si': 'K'},
#            'temperature_air_mean_005': {'origin': 'K', 'si': 'K'},
#            'temperature_air_mean_200': {'origin': 'K', 'si': 'K'},
#            'temperature_air_mean_200_last_24h': {'origin': 'K', 'si': 'K'},
#            'temperature_air_min_005_last_12h': {'origin': 'K', 'si': 'K'},
#            'temperature_air_min_200': {'origin': 'K', 'si': 'K'},
#            'temperature_dew_point_mean_200': {'origin': 'K', 'si': 'K'},
#            'visibility_range': {'origin': 'm', 'si': 'm'},
#            'water_equivalent_snow_depth_new_last_1h': {'origin': 'kg / m ** 2',
#                                                        'si': 'kg / m ** 2'},
#            'water_equivalent_snow_depth_new_last_3h': {'origin': 'kg / m ** 2',
#                                                        'si': 'kg / m ** 2'},
#            'weather_last_6h': {'origin': '-', 'si': '-'},
#            'weather_significant': {'origin': 'sign [0..95]',
#                                    'si': 'sign [0..95]'},
#            'weather_significant_last_3h': {'origin': 'sign [0..95]',
#                                            'si': 'sign [0..95]'},
#            'weather_significant_optional_last_12h': {'origin': 'sign [0..95]',
#                                                      'si': 'sign [0..95]'},
#            'weather_significant_optional_last_1h': {'origin': 'sign [0..95]',
#                                                     'si': 'sign [0..95]'},
#            'weather_significant_optional_last_24h': {'origin': 'sign [0..95]',
#                                                      'si': 'sign [0..95]'},
#            'weather_significant_optional_last_3h': {'origin': 'sign [0..95]',
#                                                     'si': 'sign [0..95]'},
#            'weather_significant_optional_last_6h': {'origin': 'sign [0..95]',
#                                                     'si': 'sign [0..95]'},
#            'wind_direction': {'origin': 'deg', 'si': 'deg'},
#            'wind_gust_max_last_12h': {'origin': 'm / s', 'si': 'm / s'},
#            'wind_gust_max_last_1h': {'origin': 'm / s', 'si': 'm / s'},
#            'wind_gust_max_last_3h': {'origin': 'm / s', 'si': 'm / s'},
#            'wind_speed': {'origin': 'm / s', 'si': 'm / s'}},
#  'small': {'cloud_cover_above_7_km': {'origin': 'pct', 'si': 'pct'},
#            'cloud_cover_below_1000_ft': {'origin': 'pct', 'si': 'pct'},
#            'cloud_cover_below_500_ft': {'origin': 'pct', 'si': 'pct'},
#            'cloud_cover_between_2_to_7_km': {'origin': 'pct', 'si': 'pct'},
#            'cloud_cover_effective': {'origin': 'pct', 'si': 'pct'},
#            'cloud_cover_total': {'origin': 'pct', 'si': 'pct'},
#            'precipitation_height_significant_weather_last_1h': {'origin': 'kg '
#                                                                           '/ m '
#                                                                           '** '
#                                                                           '2',
#                                                                 'si': 'kg / m '
#                                                                       '** 2'},
#            'precipitation_height_significant_weather_last_3h': {'origin': 'kg '
#                                                                           '/ m '
#                                                                           '** '
#                                                                           '2',
#                                                                 'si': 'kg / m '
#                                                                       '** 2'},
#            'pressure_air_site_reduced': {'origin': 'Pa', 'si': 'Pa'},
#            'probability_fog_last_12h': {'origin': 'pct', 'si': 'pct'},
#            'probability_fog_last_1h': {'origin': 'pct', 'si': 'pct'},
#            'probability_fog_last_6h': {'origin': 'pct', 'si': 'pct'},
#            'probability_precipitation_height_gt_0_0_mm_last_12h': {'origin': 'pct',
#                                                                    'si': 'pct'},
#            'probability_precipitation_height_gt_0_2_mm_last_12h': {'origin': 'pct',
#                                                                    'si': 'pct'},
#            'probability_precipitation_height_gt_0_2_mm_last_24h': {'origin': 'pct',
#                                                                    'si': 'pct'},
#            'probability_precipitation_height_gt_0_2_mm_last_6h': {'origin': 'pct',
#                                                                   'si': 'pct'},
#            'probability_precipitation_height_gt_1_0_mm_last_12h': {'origin': 'pct',
#                                                                    'si': 'pct'},
#            'probability_precipitation_height_gt_5_0_mm_last_12h': {'origin': 'pct',
#                                                                    'si': 'pct'},
#            'probability_precipitation_height_gt_5_0_mm_last_24h': {'origin': 'pct',
#                                                                    'si': 'pct'},
#            'probability_precipitation_height_gt_5_0_mm_last_6h': {'origin': 'pct',
#                                                                   'si': 'pct'},
#            'probability_wind_gust_ge_25_kn_last_12h': {'origin': 'pct',
#                                                        'si': 'pct'},
#            'probability_wind_gust_ge_40_kn_last_12h': {'origin': 'pct',
#                                                        'si': 'pct'},
#            'probability_wind_gust_ge_55_kn_last_12h': {'origin': 'pct',
#                                                        'si': 'pct'},
#            'radiation_global': {'origin': '% [0..80]', 'si': '% [0..80]'},
#            'sunshine_duration': {'origin': 's', 'si': 's'},
#            'temperature_air_max_200': {'origin': 'K', 'si': 'K'},
#            'temperature_air_mean_005': {'origin': 'K', 'si': 'K'},
#            'temperature_air_mean_200': {'origin': 'K', 'si': 'K'},
#            'temperature_air_min_200': {'origin': 'K', 'si': 'K'},
#            'temperature_dew_point_mean_200': {'origin': 'K', 'si': 'K'},
#            'visibility_range': {'origin': 'm', 'si': 'm'},
#            'water_equivalent_snow_depth_new_last_1h': {'origin': 'kg / m ** 2',
#                                                        'si': 'kg / m ** 2'},
#            'water_equivalent_snow_depth_new_last_3h': {'origin': 'kg / m ** 2',
#                                                        'si': 'kg / m ** 2'},
#            'weather_last_6h': {'origin': '-', 'si': '-'},
#            'weather_significant': {'origin': 'sign [0..95]',
#                                    'si': 'sign [0..95]'},
#            'wind_direction': {'origin': 'deg', 'si': 'deg'},
#            'wind_gust_max_last_12h': {'origin': 'm / s', 'si': 'm / s'},
#            'wind_gust_max_last_1h': {'origin': 'm / s', 'si': 'm / s'},
#            'wind_gust_max_last_3h': {'origin': 'm / s', 'si': 'm / s'},
#            'wind_speed': {'origin': 'm / s', 'si': 'm / s'}}}

# %%
selected_stations=pd.read_pickle("../data/Stations_filtered_ids/selected_stations.pkl")
print(selected_stations.head())
selected_mosmix_ids=selected_stations.mosmix_id.tolist()
selected_historical_ids=selected_stations.Stations_id.tolist()
print(selected_mosmix_ids)
print(selected_historical_ids)
# Out:
#    Stations_id  von_datum  bis_datum  Stationshoehe  geoBreite  geoLaenge  \
# 0          183   19730101   20220909             42    54.6791    13.4344
# 1          701   19490101   20220915              7    53.5332     8.5761
# 2          856   19910101   20220915            551    47.8843    12.5404
# 3          953   19550101   20220915            481    49.7619     7.0542
# 4          963   19940103   20220915             38    52.5881     8.3424
#
#   Stationsname              Bundesland mosmix_id
# 0       Arkona  Mecklenburg-Vorpommern     10091
# 1  Bremerhaven                  Bremen     10129
# 2     Chieming                  Bayern     10982
# 3   Deuselbach         Rheinland-Pfalz     10615
# 4     Diepholz           Niedersachsen     10321
# ['10091', '10129', '10982', '10615', '10321', '10803', '10365', '10168', '10015', '10548', '10776', '10731']
# [183, 701, 856, 953, 963, 1443, 1605, 1694, 2115, 3231, 4104, 4177]

# %%
start_date="2021-01-01 00:00:00+00:00"
end_date="2021-12-31 23:59:00+00:00"
parameters = ["wind_speed", "sunshine_duration", "pressure_air_site_reduced", "temperature_air_mean_200", "cloud_cover_total"]
mosmix_ids=[str(i).zfill(5) for i in selected_mosmix_ids]
historical_ids = [str(i).zfill(5) for i in selected_historical_ids]
print(mosmix_ids)
print(historical_ids)
# date=pd.date_range(start_date, end_date, freq="H")
# Out:
# ['10091', '10129', '10982', '10615', '10321', '10803', '10365', '10168', '10015', '10548', '10776', '10731']
# ['00183', '00701', '00856', '00953', '00963', '01443', '01605', '01694', '02115', '03231', '04104', '04177']

# %% [markdown]
# header = pd.MultiIndex.from_product([station_ids, parameters], names=['station_id', 'parameter'])
# total_df=pd.DataFrame(columns=header)
#
# total_df.loc[:,("date", "date")]=date
# total_df.loc[:,("date", "timestamp")]=date.astype('int64')//10**9
#
# for parameter in parameters:
#     # station = dwd_request(parameter, start_date, end_date, station_ids)
#     for id in station_ids:
#         print("Receiving: ", parameter, " from station ", id)
#         station = dwd_request(parameter, start_date, end_date, id)
#         df = station.values.all().df
#         # print(df.value.head())
#         # total_df.loc[:, (id, parameter)]=df.value.copy()
#         data_df[id]=df.value.copy()
#
# #total_df.head(30)

# %%
def get_weatherdata(parameter, mosmix_ids, historical_ids):
    data_df=pd.DataFrame(columns = historical_ids)
    print("Receiving: ", parameter, " from stations: \n", mosmix_ids, "\n", historical_ids)
    for n, id in enumerate(mosmix_ids):
        stations = mosmix_request(parameter, id)
        response = stations.values.all()
        df=response.df
        # print(df)
        # print(df.tail())
        data_df[historical_ids[n]]=df.value
    data_df["date"]=df.date
    data_df["timestamp"]=data_df["date"].astype('int64')//10**9
    return data_df

# %%
for parameter in parameters:
    data_df = get_weatherdata(parameter, mosmix_ids, historical_ids)
    data_df
    data_df.fillna(0)
    path="../data/weather_forecasts/"+parameter+".pkl"
    print(path)
    data_df.to_pickle(path)
# Out:
# Receiving:  wind_speed  from stations:
#  ['10091', '10129', '10982', '10615', '10321', '10803', '10365', '10168', '10015', '10548', '10776', '10731']
#  ['00183', '00701', '00856', '00953', '00963', '01443', '01605', '01694', '02115', '03231', '04104', '04177']
# ../data/weather_forecasts/wind_speed.pkl
# Receiving:  sunshine_duration  from stations:
#  ['10091', '10129', '10982', '10615', '10321', '10803', '10365', '10168', '10015', '10548', '10776', '10731']
#  ['00183', '00701', '00856', '00953', '00963', '01443', '01605', '01694', '02115', '03231', '04104', '04177']
# ../data/weather_forecasts/sunshine_duration.pkl
# Receiving:  pressure_air_site_reduced  from stations:
#  ['10091', '10129', '10982', '10615', '10321', '10803', '10365', '10168', '10015', '10548', '10776', '10731']
#  ['00183', '00701', '00856', '00953', '00963', '01443', '01605', '01694', '02115', '03231', '04104', '04177']
# ../data/weather_forecasts/pressure_air_site_reduced.pkl
# Receiving:  temperature_air_mean_200  from stations:
#  ['10091', '10129', '10982', '10615', '10321', '10803', '10365', '10168', '10015', '10548', '10776', '10731']
#  ['00183', '00701', '00856', '00953', '00963', '01443', '01605', '01694', '02115', '03231', '04104', '04177']
# ../data/weather_forecasts/temperature_air_mean_200.pkl
# Receiving:  cloud_cover_total  from stations:
#  ['10091', '10129', '10982', '10615', '10321', '10803', '10365', '10168', '10015', '10548', '10776', '10731']
#  ['00183', '00701', '00856', '00953', '00963', '01443', '01605', '01694', '02115', '03231', '04104', '04177']
# ../data/weather_forecasts/cloud_cover_total.pkl

# %%
parameter=parameters[2]
print(parameter)
path="../data/weather_forecasts/"+parameter+".pkl"
new_df=pd.read_pickle(path)
new_df.describe()
# Out:
# pressure_air_site_reduced
#                00183          00701          00856          00953  \
# count     247.000000     247.000000     247.000000     247.000000
# mean   100922.186235  100875.829960  101321.376518  101158.097166
# std       727.791568     703.935525     535.088064     541.249704
# min     99870.000000   99660.000000  100220.000000  100030.000000
# 25%    100330.000000  100400.000000  101050.000000  100930.000000
# 50%    100830.000000  100800.000000  101350.000000  101220.000000
# 75%    101360.000000  101330.000000  101580.000000  101330.000000
# max    102560.000000  102480.000000  102580.000000  102490.000000
#
#                00963          01443          01605          01694  \
# count     247.000000     247.000000     247.000000     247.000000
# mean   100922.550607  101274.777328  101049.230769  100930.971660
# std       694.772271     455.716905     695.664138     721.119181
# min     99660.000000  100260.000000   99860.000000   99740.000000
# 25%    100470.000000  101135.000000  100595.000000  100435.000000
# 50%    100910.000000  101310.000000  101070.000000  100900.000000
# 75%    101340.000000  101440.000000  101405.000000  101315.000000
# max    102500.000000  102430.000000  102610.000000  102570.000000
#
#                02115          03231          04104          04177  \
# count     247.000000     247.000000     247.000000     247.000000
# mean   100815.141700  101177.206478  101278.340081  101201.902834
# std       720.255629     615.904954     582.689375     524.277302
# min     99590.000000  100010.000000  100110.000000  100050.000000
# 25%    100270.000000  100845.000000  100950.000000  100955.000000
# 50%    100770.000000  101250.000000  101330.000000  101250.000000
# 75%    101315.000000  101440.000000  101580.000000  101420.000000
# max    102420.000000  102650.000000  102600.000000  102450.000000
#
#           timestamp
# count  2.470000e+02
# mean   1.664262e+09
# std    2.572090e+05
# min    1.663819e+09
# 25%    1.664041e+09
# 50%    1.664262e+09
# 75%    1.664483e+09
# max    1.664705e+09

# %%
# new_df=new_df.fillna(0)
# new_df.to_pickle(path)
